# %% [markdown]
# <a href="https://colab.research.google.com/github/suvasis7/Info_miners_3/blob/main/Kaggle_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q kaggle

# %%
mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json

# %%
import numpy as np
import pandas as pd

# %%
df_m = pd.read_csv('/content/deliveries.csv')
df_m.head()
# Out:
#    match_id   season  start_date                             venue  innings  \
# 0         1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad        1
# 1         1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad        1
# 2         1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad        1
# 3         1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad        1
# 4         1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad        1
#
#    ball batting_team bowling_team      striker  non_striker  ... extras  \
# 0   0.1      England  New Zealand  JM Bairstow     DJ Malan  ...      0
# 1   0.2      England  New Zealand  JM Bairstow     DJ Malan  ...      0
# 2   0.3      England  New Zealand  JM Bairstow     DJ Malan  ...      0
# 3   0.4      England  New Zealand     DJ Malan  JM Bairstow  ...      0
# 4   0.5      England  New Zealand  JM Bairstow     DJ Malan  ...      0
#
#    wides  noballs  byes  legbyes  penalty  wicket_type  player_dismissed  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Instantiate the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the categorical variable
df_m['venue'] = label_encoder.fit_transform(df_m['venue'])

# Display the encoded DataFrame
df_m.head()
# Out:
#    match_id   season  start_date  venue  innings  ball batting_team  \
# 0         1  2023/24  2023-10-05      7        1   0.1      England
# 1         1  2023/24  2023-10-05      7        1   0.2      England
# 2         1  2023/24  2023-10-05      7        1   0.3      England
# 3         1  2023/24  2023-10-05      7        1   0.4      England
# 4         1  2023/24  2023-10-05      7        1   0.5      England
#
#   bowling_team      striker  non_striker  ... extras  wides  noballs  byes  \
# 0  New Zealand  JM Bairstow     DJ Malan  ...      0    NaN      NaN   NaN
# 1  New Zealand  JM Bairstow     DJ Malan  ...      0    NaN      NaN   NaN
# 2  New Zealand  JM Bairstow     DJ Malan  ...      0    NaN      NaN   NaN
# 3  New Zealand     DJ Malan  JM Bairstow  ...      0    NaN      NaN   NaN
# 4  New Zealand  JM Bairstow     DJ Malan  ...      0    NaN      NaN   NaN
#
#    legbyes  penalty  wicket_type  player_dismissed other_wicket_type  \
# ...

# %%
pd.crosstab(df_m['venue'] ,df_m['bowling_team'])
# Out:
# bowling_team  Afghanistan  Australia  Bangladesh  England  India  Netherlands  \
# venue
# 0                     464        133           0      308    309          312
# 1                       0        577           0      303    215          297
# 2                       0          0         503        0      0          260
# 3                     213        314         532      293    307          263
# 4                       0        284           0      157      0            0
# 5                     617        254         267        0    303            0
# 6                     302          0         253        0    305            0
# 7                       0          0           0      221    258            0
# 8                       0          0           0        0      0          606
# 9                       0          0         307      310      0            0
#
# bowling_team  New Zealand  Pakistan  South Africa  Sri Lanka
# venue
# ...

# %%
pd.crosstab(df_m['venue'] ,df_m['batting_team'])
# Out:
# batting_team  Afghanistan  Australia  Bangladesh  England  India  Netherlands  \
# venue
# 0                     617        312           0      248    216          133
# 1                       0        469           0      215    303          319
# 2                       0          0         536        0      0          306
# 3                     228        304         506      304    292          276
# 4                       0        313           0      204      0            0
# 5                     516        303         308        0    254            0
# 6                     280          0         305        0    253            0
# 7                       0          0           0      304    184            0
# 8                       0          0           0        0      0          536
# 9                       0          0         294      138      0            0
#
# batting_team  New Zealand  Pakistan  South Africa  Sri Lanka
# venue
# ...
